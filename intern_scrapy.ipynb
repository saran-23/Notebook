# %% [markdown]
# <a href="https://colab.research.google.com/github/saran-23/Notebook/blob/main/intern_scrapy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests


URL = 'https://in.seamsfriendly.com/?utm_source=google.com&utm_medium=organic'
content = requests.get(URL)
soup = BeautifulSoup(content.text,'lxml')

items = soup.findAll('div', class_='Collapsible')

for item in items:

  print(items)
  # print(items)
  # print(item)
# Out:
# [<div class="Collapsible"><a class="Collapsible__Button Heading Link Link--primary u-h6" href="/collections/new-arrivals"><dep>New Arrivals ✨</dep></a></div>, <div class="Collapsible"><a class="Collapsible__Button Heading Link Link--primary u-h6" href="/collections/best-sellers"><dep>Best Sellers 🔥</dep></a></div>, <div class="Collapsible"><a class="Collapsible__Button Heading Link Link--primary u-h6" href="/collections/dresses"><dep>Dresses (464)</dep></a></div>, <div class="Collapsible"><a class="Collapsible__Button Heading Link Link--primary u-h6" href="/collections/jumpsuits"><dep>Jumpsuits (112)</dep></a></div>, <div class="Collapsible"><a class="Collapsible__Button Heading Link Link--primary u-h6" href="/collections/topwear"><dep>Tops (438)</dep></a></div>, <div class="Collapsible"><a class="Collapsible__Button Heading Link Link--primary u-h6" href="/collections/pants"><dep>Pants (175)</dep></a></div>, <div class="Collapsible"><a class="Collapsible__Button Heading Link Link--pr
# ...

# %%
# TITLE AND PRICES
price=soup.find('span')
prices=soup.find_all('span')
for price in prices:
  print(price.get_text())

# section = soup.find('section')
# soup.span['class']
# Out:
# Shopping Cart  FREE SHIPPING
#
# Order Today to get it by
#
#  FREE SHIPPING
#
#
#
#
#
#
#
# sEARCH sTROKE 2
# hamburger
# .cls-1{fill:#1e352e;}Asset 35
# New ✨
# Best Sellers 🔥
# Dresses
#
# Jumpsuits
#
# Tops
#
# Skirts
#
# Shorts
#
#
# Pants
#
# Outerwear
#
#
# Co-ords
# Collections
#
#
# Plus Size
# Petite
# Tall
#
# sEARCH sTROKE 2
# 0
#
#
#
# .cls-2{fill:#fff;}Empty cart stroke 2
# 0
#
#
#
#
# .cls-2{fill:#fff;}Empty cart stroke 2
# 0
#
# 0
#
# ₹6,030
#
#
#
#
#
#
#  3 reviews
#
# ₹5,750
#
#
#
#
#
#
#  No reviews
#
# ₹4,280
#
#
#
#
#
#
#  No reviews
#
# ₹5,440
#
#
#
#
#
#
#  2 reviews
#
# ₹5,570
#
#
#
#
#
#
#  No reviews
#
# ₹4,230
#
#
#
#
#
#
#  3 reviews
#
# ₹4,900
#
#
#
#
#
#
#  No reviews
#
# ₹3,510
#
#
#
#
#
#
#  No reviews
#
# ₹5,720
#
#
#
#
#
#
#  No reviews
#
# ₹3,110
#
#
#
#
#
#
#  No reviews
#
# ₹3,970
#
#
#
#
#
#
#  3 reviews
#
# On sale
# ₹5,050
# ₹5,300
#
#
#
#
#
#
#  3 reviews
#
# ₹4,410
#
#
#
#
#
#
#  29 reviews
#
# ₹4,510
#
#
#
#
#
#
#  16 reviews
#
# ₹6,350
#
#
# ...

# %%
# WORKING (IMAGES)
for image in soup.find_all('img'):
    print(image.get('src'))
# Out:
# https://cdn.shopify.com/s/files/1/0050/3264/0601/files/SB_Banner-2.jpg?v=1636460909
# https://cdn.shopify.com/s/files/1/0050/3264/0601/files/truck.png?v=1613617468
# https://cdn.shopify.com/s/files/1/0050/3264/0601/files/PRA_0018_1-2.jpg?v=1630420995
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# //cdn.shopify.com/s/files/1/0534/2501/2925/files/Website_Logo_c0eccf22-f183-4903-8109-0b8f2a641154_260x.png?v=1638353558
# https://cdn.shopify.com/s/files/1/0534/2501/2925/files/mobile-search.svg?v=1623308203
# //cdn.shopify.com/s/files/1/0534/2501/2925/files/M_Banner_Jan_22_1_600x.jpg?v=1641370187
# None
# None
# None
# https://cdn.shopify.com/s/files/1/0050/3264/0601/files/handdown.png?v=1613600415
# https://cdn.shopify.com/s/files/1/0050/3264/0601/files/handdown.png?v=1613600415
# https://cdn.shopify.com/s/files/1/0050/3264/0601/files/Vector.svg?v=1637086220
# https://cdn.shopify.com/s/files/1/0050/3264/0601/files/Group_254.svg?v=1637086220
# ...

# %%
#

# %%
# Out:
# <title id="pi-visa">Visa</title>
# =========Text Result==========

# %%
from bs4 import BeautifulSoup
import requests


URL = 'https://in.seamsfriendly.com/products/mustard-cotton-flax-strappy-slit-dress'
content = requests.get(URL)
soup = BeautifulSoup(content.text,'html.parser')

# %%
class Item:
  def __init__(self ,sno, name, price, image_url):
    self.sno = sno
    self.name = name
    self.price = price
    self.image_url = if image_url is None "default" else image_url
    self.hasImage = image_url is not None

  def __repr__(self):
    return f'Item {self.sno}.{self.name} ${self.price} picture {self.image_url}'

Item(1,"Apple", 25, "kjfhkrfk")

# %%
def write_csv(items):

# %%
price = int(soup.find("span",class_="ProductMeta__Price").text.replace(",","").replace("₹",""))
# price = (soup.find("span",class_="ProductMeta__Price").text)
[Item(1,"naME",price,"jhguhguijy")]
# Out:
# [Item 1.naME $2550 picture jhguhguijy]
